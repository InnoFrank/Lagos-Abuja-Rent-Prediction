# %% [markdown]
# # Project Setup
# ## Lagos & Abuja Rent Prediction
# ## 3MTT Capstone Project

# %%
print("Hello, Lagos Rent Prediction Project!")
# Out:
# Hello, Lagos Rent Prediction Project!

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
np.__version__
# Out:
# '2.4.6'

# %%
plt.__version__
# Out:
# '3.11.0'

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
import numpy as np
numbers = np.array([10, 20, 30, 40, 50])
print(numbers)
# Out:
# [10 20 30 40 50]

# %%
rent = 3500000
print(rent)
# Out:
# 3500000

# %%
rent = 3500000
location = "Lekki"
rating = 4.8
serviced = True

print(type(rent))
print(type(location))
print(type(rating))
print(type(serviced))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
bedroom = [2, 3, 4, 1, 5]

# %%
bedrooms = [2, 3, 4, 1, 5]
print(bedrooms)
# Out:
# [2, 3, 4, 1, 5]

# %%
print(bedrooms[0])
# Out:
# 2

# %%
print(bedrooms[2])
# Out:
# 4

# %%
house = {"bedrooms": 3,"Bathrooms": 4,"Location": "Lekki","Rent": 3500000}

# %%
house = {"bedrooms": 3,"Bathrooms": 4,"Location": "Lekki","Rent": 3500000}
print(house)
# Out:
# {'bedrooms': 3, 'Bathrooms': 4, 'Location': 'Lekki', 'Rent': 3500000}

# %%
print(rent)
# Out:
# 3500000

# %%
print(bedrooms)
# Out:
# [2, 3, 4, 1, 5]
